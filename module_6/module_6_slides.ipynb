# %% [markdown]
# # Session 6: Web Scraping 1
# *Hjalte Fejerskov Boas*

# %% [markdown]
# # About me
#
# - PhD student in Economics at UCPH
#     - At the moment: working on a project about combatting tax havens
# - Master and bachelor from UCPH
# - Had this course in 2017
# - Personal website: https://www.hjalteboas.com/

# %% [markdown]
# ## Recap
# In session 5 you briefly touched upon extracting data from the internet
# - You heard about HTTP requests: The computer's way to communicate with the website and underlying server
# - You learned about HTML: The language behind a website
# - You worked with APIs: A way to retrieve structured data from websites
#     - You learned how to send requests to an API and in return recieve the desired data
#     - You learned how to deal with the JSON files that is usually how the data is sent

# %% [markdown]
# In the next three sessions we will build on your newly acquired skills
#
# You will learn how to extract data from websites when no API is available
#
# It will open up a whole new world of data possibilities!

# %% [markdown]
# ## Required readings
#
# - [Beautiful Soup: Build a Web Scraper With Python](https://realpython.com/beautiful-soup-web-scraper-python/)
#
# - [A Practical Introduction to Web Scraping in Python](https://realpython.com/python-web-scraping-practical-introduction/)
#
# - Shiab, Nael. 2015. [On the Ethics of Web Scraping and Data Journalism](http://gijn.org/2015/08/12/on-the-ethics-of-web-scraping-and-data-journalism/). Global Investigative Journalism Network.

# %% [markdown]
# ## Overview of Session 6
#
# Today, we will learn about interacting with websites and extracting their unstructured data (web scraping). In particular, we will cover:
# 1. Basics of web scraping:
#     - What is web scraping?
#     - How is a webpage built? How does a computer "see" a webpage?
#     - Ethical considerations
# 2. Mapping the URLs of the webpages you want to scrape:
#     - How can we systematically go through all the webpages and scrape their content?
#         - You will learn to exploit the pattern in the URLs
# 3. Connecting to a webpage:
#     - How do we extract the HTML-string behind the webpage?
# 4. Good practices of web scraping
#     - Limit the rate of your calls to the webpage
#     - Logging
#     - Handle exceptions
# 5. Exploiting the webpage's own data requests to extract data easily
#     - Use the network panel in Chrome Developer Tools to locate the data

# %% [markdown]
# ## What is web scraping?
#
# Web scraping is the practice of extracting information from websites in an automated and structured way
#
# - The internet is the biggest source of information/data you can find! [90% of the data on the internet has been created since 2016](https://blog.microfocus.com/how-much-data-is-created-on-the-internet-each-day/)
# - Web scraping unlock this new world of data possibilities
# - The biggest limitation is your own imagination!

# %% [markdown]
# #### One note:
# - Learning how to web scrape may be frustrating in the beginning
#     - It is a new way of thinking data
#     - It requires technological knowledge
# - Keep working with it!
#     - I promise you; you will master it
#     - And the internet will never be the same again

# %% [markdown]
# ## How a human sees a webpage vs. how a computer sees it

# %% [markdown]
# ### [www.jobnet.dk](https://job.jobnet.dk/CV/FindWork?Offset=0&SortValue=BestMatch)
#
# How a human sees a webpage             |  How a computer sees a webpage
# :-------------------------:|:-------------------------:
# ![](https://drive.google.com/uc?exportview&id=1cbrC303j-gQnXbXyTEQBPT2xH7kgz6Cy)  |  ![](https://drive.google.com/uc?export=view&id=1VFlfDcJHCzbtmkpr4kvXzGecrDE7KmLY)

# %% [markdown]
# ## Ethical Considerations (rule of thumbs)
# 1. Fair use: Take only the stuff you need
# 2. Be careful with copyrighted material
# 3. If a regular user can’t access it, we shouldn’t try to get it: [That is considered hacking](https://www.dr.dk/nyheder/penge/gjorde-opmaerksom-paa-cpr-hul-nu-bliver-han-politianmeldt-hacking)
# 4. If monetizing on the data, be careful not to be in direct competition with whom you are taking the data from
# 5. LinkedIn case: [Scraping data on LinkedIn is legal](https://gizmodo.com/linkedin-scraping-data-legal-court-case-1848811335)
# 6. Don't hit it too fast: Essentially a DENIAL OF SERVICE attack (DOS); [Again considered hacking](https://www.dr.dk/nyheder/indland/folketingets-hjemmeside-ramt-af-hacker-angreb)

# %% [markdown]
# <img src="https://github.com/snorreralund/images/raw/master/Sk%C3%A6rmbillede%202017-08-03%2014.46.32.png"/>

# %% [markdown]
# ## The Web Scraping Recipe
#
# Three (main) steps in scraping:
# 1. **MAPPING (this session)**: Find URLs of the webpages containing the information you want.
# 2. **DOWNLOADING (this session)**: Download the HTML of the webpages.
# 3. **PARSING (session 7)**: Extract the information from the HTML.

# %% [markdown]
# ### What browser to use?
# - Lectures and exercises are solely based on Chrome as my browser --> I recommend you to use Chrome as well.
# - All browsers (Chrome, Firefox, Safari, Edge etc.) can be used to investigate the webpages like you will learn to do here
#     - The practice might differ a bit

# %%
import requests
import time
import tqdm
import pandas as pd
import os
import json

# %% [markdown]
# # Video 6.1: Mapping URLs and downloading webpage content

# %% [markdown]
# ## 1. Mapping: How do we find the relevant URLs

# %% [markdown]
# ### Navigating websites to collect links
#
# How can you automate the navigation of links?

# %% [markdown]
# ### Building URLs using a recognizable pattern
# A nice trick is to understand how URLs are constructed to communicate with a server
#
# This will allow us to navigate the page:
#
# * / is like folders on your computer.
# * ? entails the start of a query with parameters
# * = defines a variable: e.g. page=1000 or offset = 100 or showNumber=20
# * & separates different parameters.
# * \+ is html for whitespace

# %% [markdown]
# Lets look at how [www.jobindex.dk](https://www.jobindex.dk/jobsoegning) does it:
# - We simply click around and take note at how the address line changes

# %% [markdown]
# #### We want to create the URLs for the first 5 pages
# Is there a pattern in the URL that we can exploit?

# %%
links = []
for page in range(1,6,1):
    url = f'https://www.jobindex.dk/jobsoegning?page={page}'
    links.append(url)

# %%
links
# Out:
# ['https://www.jobindex.dk/jobsoegning?page=1',
#  'https://www.jobindex.dk/jobsoegning?page=2',
#  'https://www.jobindex.dk/jobsoegning?page=3',
#  'https://www.jobindex.dk/jobsoegning?page=4',
#  'https://www.jobindex.dk/jobsoegning?page=5']

# %% [markdown]
# ## 2. Connect to the webpage and *download* its content

# %% [markdown]
# ### Here is how you connect to and download the HTML of a webpage

# %%
import requests
response = requests.get('https://www.jobindex.dk/jobsoegning?page=1')

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/mapbox-gl/dist/mapbox-gl.css?h=0221a0dab467f93c80e8f5264c4f146e6d11496d" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.css?h=d9a237c8b02816a196adb454f5a8184ed17d80a7" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.css?h=f908f8924442cd3fc8a7a73091bace3860f3d8a2" rel="stylesheet"><link href="/css/_scss/themes/jobindex.css?h=0578c1101b9b7ad8ba9d7facb2e4e2eee58bb261" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    \n    <meta content="https://www.jobindex.dk/jobsoegning" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?lang=da" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning?format=xml" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"89970439e074e40a6901e5a0b246c552097479b6","lang":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":182,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{"find_company":"\\/jobagent\\/virksomhed"},"archive":{"maxdate":20220728,"mindate":20220428},"enable_advanced":true}},"jobsearch\\/saved_search":{"formSelector":"#save_search_form"},"jobsearch\\/search":{"ajax_error_text":"Noget gik galt med jobsøgningen. Prøv ig ...

# %% [markdown]
# #### Remember to tell who you are
# - Write your name and email in the header of the request you send to the webpage
# - Then the managers of the webpage will know you are not a malicious actor

# %%
response = requests.get('https://www.jobindex.dk/jobsoegning?page=1', headers={'name':'Hjalte Fejerskov Boas','email':'hfb@econ.ku.dk'})

# %% [markdown]
# ### We now want to download the content of all 5 links we made earlier

# %%
list_htmls = []
for url in links:
    response = requests.get(url)
    html = response.text
    list_htmls.append(html)

# %%
#list_htmls

# %% [markdown]
# #### It is good practice to limit the rate of your calls to the website
#
# You can do that with the function `time.sleep()`

# %%
import time
import tqdm

# %%
list_htmls = []
for url in tqdm.tqdm(links): #Track the time left before completing the loop
    response = requests.get(url)
    html = response.text
    list_htmls.append(html)
    time.sleep(0.5) #Sleep for 0.5 seconds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ss/pvm65dps049d1q9czm5j5qhm0000gn/T/ipykernel_14352/64905627.py in <module>
#       1 list_htmls = []
# ----> 2 for url in tqdm.tqdm(links): #Track the time left before completing the loop
#       3     response = requests.get(url)
#       4     html = response.text
#       5     list_htmls.append(html)
#
# NameError: name 'tqdm' is not defined

# %% [markdown]
# # Video 6.2: Logging and handling exceptions

# %% [markdown]
# ## Logging
# Logging your web scraping activity is crucial to ensuring and demonstrating data quality. It helps you:
# - to document the data you extract
# - to understand the reasons behind any unexpected stops of your web scraper

# %% [markdown]
# ### Minimum essentials to log
# - *Time* of the scrape
# - The *status code* of the request response
#     - If succesful, the status code is normally *200*
#     - A common error is *404*: "*Page not found*"
# - The *length* of the output
#     - To indicate whether there may be a mistake
#     - In our case the output is usually an HTML-string
# - The *path* to the output file
#     - What did we actually scrape?

# %% [markdown]
# #### Here is a simple logging function that you can use:

# %%
import os, sys

# %%
# Define the log function to gather the log information
def log(response,logfile,output_path=os.getcwd()):
    # Open or create the csv file
    if os.path.isfile(logfile): #If the log file exists, open it and allow for changes     
        log = open(logfile,'a')
    else: #If the log file does not exist, create it and make headers for the log variables
        log = open(logfile,'w')
        header = ['timestamp','status_code','length','output_file']
        log.write(';'.join(header) + "\n") #Make the headers and jump to new line
        
    # Gather log information
    status_code = response.status_code #Status code from the request result
    timestamp = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())) #Local time
    length = len(response.text) #Length of the HTML-string
    
    # Open the log file and append the gathered log information
    with open(logfile,'a') as log:
        log.write(f'{timestamp};{status_code};{length};{output_path}' + "\n") #Append the information and jump to new line

# %% [markdown]
# #### Apply to web scrape:

# %%
list_htmls = []
logfile = 'log.csv'
for url in tqdm.tqdm(links):
    response = requests.get(url)
    html = response.text
    list_htmls.append(html)
    time.sleep(0.5)
    log(response,logfile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ss/pvm65dps049d1q9czm5j5qhm0000gn/T/ipykernel_14352/4040679195.py in <module>
#       1 list_htmls = []
#       2 logfile = 'log.csv'
# ----> 3 for url in tqdm.tqdm(links):
#       4     response = requests.get(url)
#       5     html = response.text
#
# NameError: name 'tqdm' is not defined

# %% [markdown]
# ## Handling exceptions
# When you web scrape you will encounter unexpected errors or crashes.
# Some common errors may be:
# - The URL does not exist
# - The connection to the internet stops
#
# How can we mitigate such problems?
# - The `Try/Except` block in python can help us
#     - If the computer encounter an error then it will execute the except code block instead

# %%
list_htmls = []
for url in tqdm.tqdm(links):
    try:
        response = requests.get(url)
    except Exception as e:
        print(url) #Print url
        print(e) #Print error
        with open("list_htmls", "w") as l: #Save the list_htmls as a json file to retrieve at another time
            json.dump(list_htmls, l)
        continue #Continue to next iteration of the loop
    html = response.text
    list_htmls.append(html)
    time.sleep(0.5) #Sleep for 0.5 seconds
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:05<00:00,  1.10s/it]

# %% [markdown]
# # Video 6.3: The network panel

# %% [markdown]
# ## Background
# Many webpages are built dynamically
# - Each time you open up the webpage, it sends some **requests** to the server to retrieve the data that you see on the webpage

# %% [markdown]
# We can find these requests and use them!
# - We can then send them directly to the server
# - And then extract the data *before* it is written into the HTML
#     - Much more preferable: The data usually comes in a structured JSON format
#     - Makes it easy to use the data right away

# %% [markdown]
# ## The network panel in Chrome Developer Tools
# Use the **network panel** in the Chrome Developer Tools
# - The network panel monitors all uploads and downloads to and from the webpage
# - I.e. also requests about data we are interested in

# %% [markdown]
# ### The network panel: [www.boligsiden.dk](https://www.boligsiden.dk/tilsalg)
# <img src="https://drive.google.com/uc?export=view&id=1vGk2b1jxH1LU642-YWo1QgR3Q5vz2rQe">

# %% [markdown]
# ### Which request is the one?
# 1. We want to locate an XHR ([XMLHttpRequest](https://en.wikipedia.org/wiki/XMLHttpRequest)). The XHRs transfer data between the server and the webpage
#     - Pick "*Fetch/XHR*"
# 2. Which XHR carries the information about the properties?
#     - We need to look through them all --> You can get a preview of the JSON file in "*Preview*"
# 3. When we have found the right XHR, we need to find the request URL
#     - Go to "*Headers*". Here you see the request URL

# %% [markdown]
# ### The steps:

# %% [markdown]
# #### Send the request to the server and get the data

# %%
response = requests.get('https://api.prod.bs-aws-stage.com/search/cases?addressTypes=villa%2Ccondo%2Cterraced+house%2Choliday+house%2Ccooperative%2Cfarm%2Chobby+farm%2Cfull+year+plot%2Cvilla+apartment%2Choliday+plot&per_page=50&page=1&highlighted=true&sortAscending=true&sortBy=timeOnMarket')

# %% [markdown]
# #### Convert the data to a JSON format in Python

# %%
result = response.json()

# %% [markdown]
# #### The JSON file consists of two different key-value pairs ("cases" and "links").
# #### We are only interested in the information about properties which are stored in the "cases" key-value pair

# %%
result_properties = result['cases']

# %% [markdown]
# #### Now we can easily convert the JSON file to a pandas DataFrame

# %%
data = pd.DataFrame(result_properties)

# %%
data
# Out:
#                                                _links  \
# 0   {'self': {'href': '/cases/1634c6f4-6592-4e66-b...
# 1   {'self': {'href': '/cases/0e2339cf-2efa-4aaa-b...
# 2   {'self': {'href': '/cases/2a5eaae5-193b-4e66-9...
# 3   {'self': {'href': '/cases/09172d2a-964e-42a2-a...
# 4   {'self': {'href': '/cases/38d73064-1712-45ab-8...
# 5   {'self': {'href': '/cases/b2dbda4d-f35f-4417-9...
# 6   {'self': {'href': '/cases/7529a18d-9701-450b-b...
# 7   {'self': {'href': '/cases/b1549121-0d0b-4daf-9...
# 8   {'self': {'href': '/cases/0dd4feb9-a73e-49de-b...
# 9   {'self': {'href': '/cases/0f7a12fc-2bbc-4646-a...
# 10  {'self': {'href': '/cases/29dc5dc7-40e9-461b-8...
# 11  {'self': {'href': '/cases/d54972b7-b5f6-402b-a...
# 12  {'self': {'href': '/cases/c92169ef-8976-4751-b...
# 13  {'self': {'href': '/cases/43376511-45db-4117-b...
# 14  {'self': {'href': '/cases/3bfb4435-ee4e-43e9-b...
# 15  {'self': {'href': '/cases/9e79d228-8d9c-411c-9...
# 16  {'self': {'href': '/cases/ae8edd50-df84-4cb1-a...
# 17  {'self': {'href': '/cases/b20bb07a-d56a-42fc-b...
# 18  {'self': {'href': '/cases/0b047f34-21e5-4547-b...
# 19  {'self': {'href': '/cases/44a18e49-d708-4489-b...
# 20  {'self': {'href': '/cases/9ebf3682-bc34-480f-a...
# 21  {'self': {'href': '/cases/a7b154bc-feb4-427b-a...
# 22  {'self': {'href': '/cases/bdb5efb5-b2da-4798-9...
# 23  {'self': {'href': '/cases/0e00ffaf-c65b-4a84-8...
# 24  {'self': {'href': '/cases/5841a5e6-32b2-412f-b...
# 25  {'self': {'href': '/cases/4a2f3839-a914-4f42-a...
# 26  {'self': {'href': '/cases/1c47d0a6-81e3-4ce8-b...
# 27  {'self': {'href': '/cases/dbdcff23-ea7f-44b0-8...
# 28  {'self': {'href': '/cases/3fce7232-ac73-4900-9...
# 29  {'self': {'href': '/cases/e9b49ab6-4344-4d6a-9...
# 30  {'self': {'href': '/cases/7ff751c6-56cb-428e-8...
# 31  {'self': {'href': '/cases/9dddb092-a56e-472c-a...
# 32  {'self': {'href': '/cases/b16cb358-96c4-4fee-a...
# 33  {'self': {'href': '/cases/e9d4b626-e37c-4805-a...
# 34  {'self': {'href': '/cases/19f8cd40-ccf4-409d-a...
# 35  {'self': {'href': '/cases/7fb1d305-fbf1-423b-9...
# 36  {'self': {'href': '/cases/12f6dede-2a80-4c18-a...
# 37  {'self': {'href': '/cases/f5e2613a-8179-4410-a...
# 38  {'self': {'href': '/cases/b5e62c43-f39e-43f6-8...
# 39  {'self': {'href': '/cases/0ac72891-0c80-4a91-a...
# 40  {'self': {'href': '/cases/b4673c8c-6b4d-4ae5-8...
# 41  {'self': {'href': '/cases/96d87a54-20e2-4bd3-a...
# 42  {'self': {'href': '/cases/c22bb894-37bc-4880-9...
# 43  {'self': {'href': '/cases/34c45b47-48c2-4604-a...
# 44  {'self': {'href': '/cases/7ccfba57-2e3a-4919-9...
# 45  {'self': {'href': '/cases/7a749ab4-4646-4243-8...
# 46  {'self': {'href': '/cases/183bf3f9-bd1f-44aa-8...
# 47  {'self': {'href': '/cases/43bd496e-dc4f-446c-a...
# 48  {'self': {'href': '/cases/d7fe9601-6f81-4f6b-a...
# 49  {'self': {'href': '/cases/16da2992-21c7-4025-8...
#
#                                               address     addressType  \
# 0   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 1   {'_links': {'self': {'href': '/addresses/ef6bf...  terraced house
# 2   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 3   {'_links': {'self': {'href': '/addresses/0a3f5...  terraced house
# 4   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 5   {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 6   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 7   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 8   {'_links': {'self': {'href': '/addresses/0a3f5...  terraced house
# 9   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 10  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 11  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 12  {'_links': {'self': {'href': '/addresses/0a3f5...  full year plot
# 13  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 14  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 15  {'_links': {'self': {'href': '/addresses/0a3f5...  full year plot
# 16  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 17  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 18  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 19  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 20  {'_links': {'self': {'href': '/addresses/0a3f5...  terraced house
# 21  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 22  {'_links': {'self': {'href': '/addresses/18a9a...           villa
# 23  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 24  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 25  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 26  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 27  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 28  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 29  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 30  {'_links': {'self': {'href': '/addresses/0a3f5...   holiday house
# 31  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 32  {'_links': {'self': {'href': '/addresses/0a3f5...            farm
# 33  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 34  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 35  {'_links': {'self': {'href': '/addresses/0a3f5...     cooperative
# 36  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
#
# 46  https://www.danbolig.dk?propertyid=2260000426&...
# 47  https://www.danbolig.dk?propertyid=0140000545&...
# 48                     https://home.dk/sag/9020001225
# 49  http://www.estate-maeglerne.dk/maegler/pages/p...
#
#                                           coordinates  daysOnMarket  \
# 0   {'lat': 55.75399, 'lon': 11.708402, 'type': 'E...             1
# 1   {'lat': 55.712513, 'lon': 11.763541, 'type': '...             1
# 2   {'lat': 55.162, 'lon': 11.977034, 'type': 'EPS...             1
# 3   {'lat': 55.75249, 'lon': 11.961139, 'type': 'E...             2
# 4   {'lat': 55.25264, 'lon': 11.76687, 'type': 'EP...             2
# 5   {'lat': 55.839928, 'lon': 12.430592, 'type': '...             2
# 6   {'lat': 55.20126, 'lon': 10.775188, 'type': 'E...             2
# 7   {'lat': 55.562973, 'lon': 12.257923, 'type': '...             3
# 8   {'lat': 55.793953, 'lon': 12.488909, 'type': '...             3
# 9   {'lat': 55.54366, 'lon': 11.710705, 'type': 'E...             3
# 10  {'lat': 55.650623, 'lon': 11.505455, 'type': '...             3
# 11  {'lat': 55.72517, 'lon': 12.528069, 'type': 'E...             3
# 12  {'lat': 55.560425, 'lon': 10.653675, 'type': '...             3
# 13  {'lat': 55.542145, 'lon': 12.235708, 'type': '...             3
# 14  {'lat': 55.572998, 'lon': 12.22719, 'type': 'E...             3
# 15  {'lat': 55.54111, 'lon': 12.232681, 'type': 'E...             3
# 16  {'lat': 55.755806, 'lon': 11.646319, 'type': '...             3
# 17  {'lat': 55.79511, 'lon': 12.44813, 'type': 'EP...             3
# 18  {'lat': 55.12384, 'lon': 10.231905, 'type': 'E...             3
# 19  {'lat': 56.50835, 'lon': 9.338954, 'type': 'EP...             3
# 20  {'lat': 55.365475, 'lon': 10.364227, 'type': '...             3
# 21  {'lat': 55.526638, 'lon': 12.217414, 'type': '...             6
# 22  {'lat': 56.518223, 'lon': 9.337153, 'type': 'E...             6
# 23  {'lat': 56.31112, 'lon': 10.408041, 'type': 'E...             6
# 24  {'lat': 55.857357, 'lon': 12.430056, 'type': '...             6
# 25  {'lat': 55.537136, 'lon': 12.223899, 'type': '...             6
# 26  {'lat': 55.321514, 'lon': 10.250885, 'type': '...             6
# 27  {'lat': 55.3522, 'lon': 10.184452, 'type': 'EP...             6
# 28  {'lat': 55.5278, 'lon': 12.224072, 'type': 'EP...             7
# 29  {'lat': 55.528725, 'lon': 12.226265, 'type': '...             7
# 30  {'lat': 55.524895, 'lon': 12.220337, 'type': '...             7
# 31  {'lat': 55.67775, 'lon': 11.613816, 'type': 'E...             7
# 32  {'lat': 56.302673, 'lon': 10.696205, 'type': '...             7
# 33  {'lat': 55.09171, 'lon': 12.028487, 'type': 'E...             7
# 34  {'lat': 55.24133, 'lon': 11.772097, 'type': 'E...             7
# 35  {'lat': 55.679207, 'lon': 12.588583, 'type': '...             8
# 36  {'lat': 55.97926, 'lon': 12.413946, 'type': 'E...             8
# 37  {'lat': 56.00024, 'lon': 12.197185, 'type': 'E...             8
# 38  {'lat': 55.675476, 'lon': 12.574221, 'type': '...             8
# 39  {'lat': 55.839497, 'lon': 12.426313, 'type': '...             9
# 40  {'lat': 55.764545, 'lon': 12.506043, 'type': '...             9
# 41  {'lat': 56.437912, 'lon': 9.384663, 'type': 'E...             9
# 42  {'lat': 56.294594, 'lon': 10.443508, 'type': '...             9
# 43  {'lat': 55.826492, 'lon': 12.437822, 'type': '...             9
# 44  {'lat': 55.29829, 'lon': 9.561847, 'type': 'EP...             9
# 45  {'lat': 56.573376, 'lon': 8.734764, 'type': 'E...             9
# 46  {'lat': 56.148922, 'lon': 10.208356, 'type': '...             9
# 47  {'lat': 55.696598, 'lon': 11.725356, 'type': '...             9
# 48  {'lat': 55.033, 'lon': 10.531214, 'type': 'EPS...             9
# 49  {'lat': 55.68422, 'lon': 12.5834875, 'type': '...             9
#
#                                          defaultImage  \
# 0   {'imageSources': [{'size': {'height': 80, 'wid...
# 1   {'imageSources': [{'size': {'height': 80, 'wid...
# 2   {'imageSources': [{'size': {'height': 80, 'wid...
# 3   {'imageSources': [{'size': {'height': 80, 'wid...
# 4   {'imageSources': [{'size': {'height': 80, 'wid...
# 5   {'imageSources': [{'size': {'height': 80, 'wid...
# 6   {'imageSources': [{'size': {'height': 80, 'wid...
# 7   {'imageSources': [{'size': {'height': 80, 'wid...
# 8   {'imageSources': [{'size': {'height': 80, 'wid...
# 9   {'imageSources': [{'size': {'height': 80, 'wid...
# 10  {'imageSources': [{'size': {'height': 80, 'wid...
# 11  {'imageSources': [{'size': {'height': 80, 'wid...
# 12  {'imageSources': [{'size': {'height': 80, 'wid...
# 13  {'imageSources': [{'size': {'height': 80, 'wid...
# 14  {'imageSources': [{'size': {'height': 80, 'wid...
# 15  {'imageSources': [{'size': {'height': 80, 'wid...
# 16  {'imageSources': [{'size': {'height': 80, 'wid...
# 17  {'imageSources': [{'size': {'height': 80, 'wid...
# 18  {'imageSources': [{'size': {'height': 80, 'wid...
# 19  {'imageSources': [{'size': {'height': 80, 'wid...
# 20  {'imageSources': [{'size': {'height': 80, 'wid...
# 21  {'imageSources': [{'size': {'height': 80, 'wid...
# 22  {'imageSources': [{'size': {'height': 80, 'wid...
# 23  {'imageSources': [{'size': {'height': 80, 'wid...
# 24  {'imageSources': [{'size': {'height': 80, 'wid...
# 25  {'imageSources': [{'size': {'height': 80, 'wid...
# 26  {'imageSources': [{'size': {'height': 80, 'wid...
# 27  {'imageSources': [{'size': {'height': 80, 'wid...
# 28  {'imageSources': [{'size': {'height': 80, 'wid...
# 29  {'imageSources': [{'size': {'height': 80, 'wid...
# 30  {'imageSources': [{'size': {'height': 80, 'wid...
# 31  {'imageSources': [{'size': {'height': 80, 'wid...
# 32  {'imageSources': [{'size': {'height': 80, 'wid...
# 33  {'imageSources': [{'size': {'height': 80, 'wid...
# 34  {'imageSources': [{'size': {'height': 80, 'wid...
# 35  {'imageSources': [{'size': {'height': 80, 'wid...
# 36  {'imageSources': [{'size': {'height': 80, 'wid...
# 37  {'imageSources': [{'size': {'height': 80, 'wid...
# 38  {'imageSources': [{'size': {'height': 80, 'wid...
# 39  {'imageSources': [{'size': {'height': 80, 'wid...
# 40  {'imageSources': [{'size': {'height': 80, 'wid...
# 41  {'imageSources': [{'size': {'height': 80, 'wid...
# 42  {'imageSources': [{'size': {'height': 80, 'wid...
# 43  {'imageSources': [{'size': {'height': 80, 'wid...
# 44  {'imageSources': [{'size': {'height': 80, 'wid...
# 45  {'imageSources': [{'size': {'height': 80, 'wid...
# 46  {'imageSources': [{'size': {'height': 80, 'wid...
# 47  {'imageSources': [{'size': {'height': 80, 'wid...
# 48  {'imageSources': [{'size': {'height': 80, 'wid...
# 49  {'imageSources': [{'size': {'height': 80, 'wid...
#
#                                       descriptionBody  \
# 0   I Udby ligger denne flotte og fuldstændig nyre...
# 1   Bo i Holbæks nye parklignende område tæt på fj...
# 2   Denne bolig i Tappernøje passer perfekt til de...
# 3   Stort rækkehus på Grønnevej.Et af de eftertrag...
# 4   I et roligt kvarter i Holsted nord for Næstved...
# 5   Nu kan du komme til at bo lige i midten af bye...
# 6   VORMARK GL. SKOLE - IDEEL FOR DEN PLADSKRÆVEND...
# 7   På Vårgyvelvej 43 i Karlslunde ligger denne vi...
# 8   På en attraktiv adresse i Brede udbyder vi nu ...
# 9   Her får I et skønt byhus, der ligger centralt ...
# 10  På Rævebæk 10 i Mørkøv venter denne flotte etp...
# 11  På en super attraktiv beliggenhed, få minutter...
# 12  Midt i den fynske natur, nær Fyns Hoved, finde...
# 13  Få skridt fra stranden i Solrød Strands Gammel...
# 14  Her får I en mindre kvalitetsvilla, der fremst...
# 15  På Svend Gønges Vej 3 i Solrød Strand finder I...
# 16  Velkommen til denne flotte villa placeret midt...
# 17  Med 192 boligkvadratmeter og en 1.280 m2 stor,...
# 18  Her er så meget godt at fortælle om. Så lad os...
# 19  Albuerum, højt til himlen, udfoldelsesmulighed...
# 20  På Birkedals Allé i Odense-bydelen Dalum finde...
# 21  Få hundrede meter fra vandet ved Solrød Strand...
# 22  Velkommen til Agnetevej 15, som er en smuk og ...
# 23  Årstidernes skiften kan følges fra første park...
# 24  Sjældent udbudt villa med fantastisk beliggenh...
# 25  På Vestre Strandvej 18 i Solrød Strand finder ...
# 26  På Glentevej ligger denne herlige villa og ven...
# 27  Kun få minutters gang fra skov og åbne landska...
# 28  Denne smukke bindingsværksejendom med rødt teg...
# 29  Glæd jer til at udforske denne arkitekttegnede...
# 30  Nu kan I opføre en ejendom skabt på et bagtæpp...
# 31  Denne flotte etplansvilla i Regstrup ligger på...
# 32  Velkommen til denne fantastiske ejendom på Bal...
# 33  Der er skruet helt op for charmen i Ammendrup,...
# 34  Velkommen til denne indbydende etplansvilla, d...
# 35  .NB.FREMVISNINGER PÅ DENNE LEJLIGHED ER SAT BE...
# 36  Moderniseret og opdateret villa til den store ...
# 37  I Annisse Nord kan I glæde jer til at opleve d...
# 38  EKSKLUSIV LIEBHAVERLEJLIGHEDELEVATORSTORT GÅRD...
# 39  Det er en stor fornøjelse for danbolig Birkerø...
# 40  Hvis du laver en liste over alt, hvad du kan ø...
# 41  Ønsker du en indflytningsklar og indbydende 3-...
# 42  Velkommen til hyggelige Præstekravevej 17, med...
# 43  Leder I efter en særlig skøn og helt rolig bel...
# 44  Nord for Haderslev ligger Sillerup, hvor denne...
# 45  Nu har du chancen for, at erhverve et rigtigt ...
# 46  Sjældent udbudt 2´er med skøn udsigt over byen...
# 47  På en rolig, lukket villavej, udbydes nu denne...
# 48  I vil næppe fortryde købet af denne flotte bol...
# 49  Det er ikke hver dag, at vi har fornøjelsen af...
#
#                                      descriptionTitle  ...  \
# 0        Nyrenoveret villa i skønne omgivelser i Udby  ...
# 1     Arkitekttegnet rækkehus klos op ad fredet natur  ...
# 2   Mulighedsrig ejendom med fremragende garage i ...  ...
# 3                               Attraktiv beliggenhed  ...
# 4   Vedligeholdt etplansvilla i Holsted / Næstved ...  ...
# 5                Herskabslejlighed i centrum af byen!  ...
# 6                                                 NaN  ...
# 7   123 m2 etplansvilla i røde sten og med betonta...  ...
# 8                                                 NaN  ...
# 9         Dejligt byhus med skøn have i Store Merløse  ...
# 10               Utrolig velholdt villa midt i Mørkøv  ...
# 11  Stor, lækker lejlighed med herlig altan på sup...  ...
# 12          STOR BYGGEGRUND MED NATURSKØN BELIGGENHED  ...
# 13  165 m2 flot strandside-villa i Gammel Køgevejs...  ...
# 14  101 m2 egoistvilla i indflytningsklar stand på...  ...
# 15  790 m2 byggegrund i det meget eftertragtede Ga...  ...
# 16  Fin og rummelig villa i smukke omgivelser nær ...  ...
# 17                                                NaN  ...
# 18  Eksklusiv og stilfuld familievilla, beliggende...  ...
# 19  Ualmindelig velholdt etplansvilla på en af Løg...  ...
# 20                     HYGGELIGT ENDERÆKKEHUS I DALUM  ...
# 21  Indflytningsklar familievilla i gåafstand til ...  ...
# 22     Vidunderlig og stilren kvalitetsvilla fra 2018  ...
# 23  Arkitekttegnet villa med fantastisk udsigt til...  ...
# 24                                                NaN  ...
# 25  134 m2 indflytningsklar etplansvilla med garag...  ...
# 26   DEJLIG FAMILIEVILLA BELIGGENDE CENTRALT I BRYLLE  ...
# 27       FLOT OG VELHOLDT VILLA I TOMMERUP STATIONSBY  ...
# 28  Indbydende bindingsværkshus i anden række til ...  ...
# 29      Arkitekttegnet udsigtsvilla, der skal opleves  ...
# 30               Skøn byggegrund få skridt fra vandet  ...
# 31                  Flot og velholdt villa i Regstrup  ...
# 32         Flot nedlagt landbrug med gode udbygninger  ...
# 33                          CHARME, IDYL OG ATMOSFÆRE  ...
# 34    Totalistandsat familievilla i Kalbyriskvarteret  ...
# 35  TOTALRENOVERET EJENDOM OG LEJLIGHED PÅ SKØNNE ...  ...
# 36  Moderniseret og opdateret villa til den store ...  ...
# 37                                                NaN  ...
# 38                                                NaN  ...
# 39                                                NaN  ...
# 40                                                NaN  ...
# 41  Indflytningsklar 3-værelses ejerlejlighed med ...  ...
# 42     Hyggeligt sommerhus i Følle med skøn havudsigt  ...
# 43    Flot renoveret udsigtsvilla - energimærke A2010  ...
# 44    Villa med mulighed for udnyttelse af tagetagen.  ...
# 45  Sommerhus ved Hostrup Strand og med udsigt til...  ...
# 46                        FANTASTISK 2´ER MED UDSIGT!  ...
# 47  Velholdt, charmerende og indflytningsklar boli...  ...
# 48        Indbydende rækkehus lige ved Svendborg Sund  ...
# 49  SJÆLDENT UDBUDT LEJLIGHED I CHRISTIANSGÅRDEN M...  ...
#
#                                               realtor  \
# 0   {'_links': {'self': {'href': '/realtors/ea7520...
# 1   {'_links': {'self': {'href': '/realtors/ea7520...
# 2   {'_links': {'self': {'href': '/realtors/cb08f4...
# 3   {'_links': {'self': {'href': '/realtors/516593...
# 4   {'_links': {'self': {'href': '/realtors/cb08f4...
# 5   {'_links': {'self': {'href': '/realtors/3c9ae3...
# 6   {'_links': {'self': {'href': '/realtors/817f0a...
# 7   {'_links': {'self': {'href': '/realtors/1fdea5...
# 8   {'_links': {'self': {'href': '/realtors/22d38c...
# 9   {'_links': {'self': {'href': '/realtors/ea7520...
# 10  {'_links': {'self': {'href': '/realtors/ea7520...
# 11  {'_links': {'self': {'href': '/realtors/f33b08...
# 12  {'_links': {'self': {'href': '/realtors/afc4c7...
# 13  {'_links': {'self': {'href': '/realtors/9fe16d...
# 14  {'_links': {'self': {'href': '/realtors/1fdea5...
# 15  {'_links': {'self': {'href': '/realtors/9fe16d...
# 16  {'_links': {'self': {'href': '/realtors/ea7520...
# 17  {'_links': {'self': {'href': '/realtors/22d38c...
# 18  {'_links': {'self': {'href': '/realtors/b9a8ef...
# 19  {'_links': {'self': {'href': '/realtors/cac8fe...
# 20  {'_links': {'self': {'href': '/realtors/afc4c7...
# 21  {'_links': {'self': {'href': '/realtors/9fe16d...
# 22  {'_links': {'self': {'href': '/realtors/cac8fe...
# 23  {'_links': {'self': {'href': '/realtors/3bc2ef...
# 24  {'_links': {'self': {'href': '/realtors/2dd238...
# 25  {'_links': {'self': {'href': '/realtors/9fe16d...
# 26  {'_links': {'self': {'href': '/realtors/afc4c7...
# 27  {'_links': {'self': {'href': '/realtors/afc4c7...
# 28  {'_links': {'self': {'href': '/realtors/9fe16d...
# 29  {'_links': {'self': {'href': '/realtors/9fe16d...
# 30  {'_links': {'self': {'href': '/realtors/9fe16d...
# 31  {'_links': {'self': {'href': '/realtors/ea7520...
# 32  {'_links': {'self': {'href': '/realtors/3bc2ef...
# 33  {'_links': {'self': {'href': '/realtors/e799ab...
# 34  {'_links': {'self': {'href': '/realtors/cb08f4...
# 35  {'_links': {'self': {'href': '/realtors/6c7aed...
# 36  {'_links': {'self': {'href': '/realtors/bd1e2f...
# 37  {'_links': {'self': {'href': '/realtors/d01627...
# 38  {'_links': {'self': {'href': '/realtors/6c7aed...
# 39  {'_links': {'self': {'href': '/realtors/3c9ae3...
# 40  {'_links': {'self': {'href': '/realtors/d8a00b...
# 41  {'_links': {'self': {'href': '/realtors/cac8fe...
# 42  {'_links': {'self': {'href': '/realtors/3bc2ef...
# 43  {'_links': {'self': {'href': '/realtors/3c9ae3...
# 44  {'_links': {'self': {'href': '/realtors/7bd4f6...
# 45  {'_links': {'self': {'href': '/realtors/e4e453...
# 46  {'_links': {'self': {'href': '/realtors/0c95ce...
# 47  {'_links': {'self': {'href': '/realtors/ea7520...
# 48  {'_links': {'self': {'href': '/realtors/4d1f95...
# 49  {'_links': {'self': {'href': '/realtors/4b5b00...
#
#                                                  slug  status  \
#
#     totalClickCount totalFavourites  weightedArea  yearBuilt  basementArea  \
# 0               390               3         92.80     1910.0           NaN
# 1               529               3           NaN     2021.0           NaN
# 2               136               3        205.25     1946.0          90.0
# 3               233               0        120.00     1971.0           NaN
# 4               263               1        107.55     1966.0           NaN
# 5               375               4        146.00     1926.0           NaN
# 6               200               4        246.05     1840.0           NaN
# 7               404               3        121.65     1979.0           NaN
# 8               480               7        110.80     1944.0          32.0
# 9               291               4        177.85     1912.0          18.0
# 10              202               1        131.35     1970.0           NaN
# 11              377               2        133.00     1930.0           NaN
# 12              372               8        180.50        NaN           NaN
# 13              527               4        151.40     1986.0           NaN
# 14              298               1        102.90     1938.0           NaN
# 15              175               1         72.25     1937.0           NaN
# 16              348               4        270.20     1900.0           NaN
# 17              590               6        237.70     1954.0         100.0
# 18              190               0        195.30     1963.0           NaN
# 19              240               2        200.05     1973.0           NaN
# 20              522               0        117.40     1959.0          40.0
# 21              511               5        102.75     1937.0           NaN
# 22              392               3           NaN     2018.0           NaN
# 23             1341               5        240.40     2007.0          26.0
# 24              979               9        147.10     1952.0          53.0
# 25              643               4        142.90     1954.0           NaN
# 26              294               0        144.65     1974.0           NaN
# 27              300               0        138.20     1915.0           5.0
# 28              793               6        160.50     1934.0           NaN
# 29             1329              11           NaN     2016.0           NaN
# 30              365               0         57.25     1945.0           NaN
# 31              444               4        119.25     1983.0           NaN
# 32              402               1        130.45     1977.0           NaN
# 33              282               2        117.20     1870.0           NaN
# 34              668               1         78.75     1939.0           NaN
# 35             2373               7         89.25     1880.0           4.0
# 36              297               5        229.20     1975.0         106.0
# 37             1880              17        242.90     1963.0          29.0
# 38              750               1           NaN     1867.0           NaN
# 39              370               3        100.00     2001.0           NaN
# 40              171               3         55.00     1935.0           NaN
# 41              184               1         84.00     1980.0           NaN
# 42              814               5         76.20     1984.0           NaN
# 43              414               2        171.35     1978.0          86.0
# 44              241               1        127.40     1900.0           NaN
# 45             1359               7         56.00     1960.0           NaN
# 46              623               5           NaN     2017.0           NaN
# 47              309               3         82.40     1897.0           NaN
# 48             1400               2        147.55     1989.0           NaN
# 49              510               4         58.00     1943.0           NaN
#
#                                         nextOpenHouse  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   {'date': '2022-07-31T11:00:00Z', 'duration': 3...
# 5   {'date': '2022-07-31T11:00:00Z', 'duration': 3...
# 6                                                 NaN
# 7                                                 NaN
# 8   {'date': '2022-07-31T10:00:00Z', 'duration': 2...
# 9                                                 NaN
# 10                                                NaN
# 11  {'date': '2022-07-31T09:00:00Z', 'duration': 2...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  {'date': '2022-07-31T09:30:00Z', 'duration': 2...
# 18  {'date': '2022-07-30T08:00:00Z', 'duration': 4...
# 19                                                NaN
# 20                                                NaN
# 21  {'date': '2022-08-07T12:00:00Z', 'duration': 3...
# 22                                                NaN
# 23                                                NaN
# 24  {'date': '2022-07-31T11:30:00Z', 'duration': 3...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49  {'date': '2022-07-31T09:30:00Z', 'duration': 3...
#
#                                           cooperative
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  {'allocation': 2.381, 'associationDebt': 54639...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
# [50 rows x 35 columns]

# %% [markdown]
# ## And we have the data!
